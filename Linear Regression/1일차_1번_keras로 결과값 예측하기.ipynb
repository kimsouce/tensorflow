# %%
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow.keras.layers import Dense
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('data/trees.csv') 
data
# Out:
#     Girth  Height  Volume
# 0     8.3      70    10.3
# 1     8.6      65    10.3
# 2     8.8      63    10.2
# 3    10.5      72    16.4
# 4    10.7      81    18.8
# 5    10.8      83    19.7
# 6    11.0      66    15.6
# 7    11.0      75    18.2
# 8    11.1      80    22.6
# 9    11.2      75    19.9
# 10   11.3      79    24.2
# 11   11.4      76    21.0
# 12   11.4      76    21.4
# 13   11.7      69    21.3
# 14   12.0      75    19.1
# 15   12.9      74    22.2
# 16   12.9      85    33.8
# 17   13.3      86    27.4
# 18   13.7      71    25.7
# 19   13.8      64    24.9
# 20   14.0      78    34.5
# 21   14.2      80    31.7
# 22   14.5      74    36.3
# 23   16.0      72    38.3
# 24   16.3      77    42.6
# 25   17.3      81    55.4
# 26   17.5      82    55.7
# 27   17.9      80    58.3
# 28   18.0      80    51.5
# 29   18.0      80    51.0
# 30   20.6      87    77.0

# %%
data = np.array(data)

# %%
xdata = data[:,0:2]
ydata = data[:,[2]]

# %%
xdata
# Out:
# array([[ 8.3, 70. ],
#        [ 8.6, 65. ],
#        [ 8.8, 63. ],
#        [10.5, 72. ],
#        [10.7, 81. ],
#        [10.8, 83. ],
#        [11. , 66. ],
#        [11. , 75. ],
#        [11.1, 80. ],
#        [11.2, 75. ],
#        [11.3, 79. ],
#        [11.4, 76. ],
#        [11.4, 76. ],
#        [11.7, 69. ],
#        [12. , 75. ],
#        [12.9, 74. ],
#        [12.9, 85. ],
#        [13.3, 86. ],
#        [13.7, 71. ],
#        [13.8, 64. ],
#        [14. , 78. ],
#        [14.2, 80. ],
#        [14.5, 74. ],
#        [16. , 72. ],
#        [16.3, 77. ],
#        [17.3, 81. ],
#        [17.5, 82. ],
#        [17.9, 80. ],
#        [18. , 80. ],
#        [18. , 80. ],
#        [20.6, 87. ]])

# %%
IO = Dense(units=1, input_dim=2 )
model = Sequential( [IO] )
model.compile( loss='mean_squared_error', optimizer=Adam(0.1))
h = model.fit( xdata, ydata, epochs=1000)
# Out:
# Train on 31 samples
# Epoch 1/1000
# 31/31 [==============================] - 0s 16ms/sample - loss: 6709.8086
# Epoch 2/1000
# 31/31 [==============================] - 0s 0s/sample - loss: 5320.9917
# Epoch 3/1000
# 31/31 [==============================] - 0s 502us/sample - loss: 4101.9634
# Epoch 4/1000
# 31/31 [==============================] - 0s 30us/sample - loss: 3054.4851
# Epoch 5/1000
# 31/31 [==============================] - 0s 32us/sample - loss: 2178.4028
# Epoch 6/1000
# 31/31 [==============================] - 0s 32us/sample - loss: 1471.0396
# Epoch 7/1000
# 31/31 [==============================] - 0s 32us/sample - loss: 926.6111
# Epoch 8/1000
# 31/31 [==============================] - 0s 32us/sample - loss: 535.6178
# Epoch 9/1000
# 31/31 [==============================] - 0s 62us/sample - loss: 284.3636
# Epoch 10/1000
# 31/31 [==============================] - 0s 0s/sample - loss: 154.7987
# Epoch 11/1000
# ...

# %%
plt.plot( h.history['loss'])
plt.show()

# %%
IO.get_weights()
# Out:
# [array([[ 5.023779  ],
#         [-0.40634292]], dtype=float32),
#  array([-5.164788], dtype=float32)]

# %%
model.predict( np.array( [[8.8,10.5]] ) )
# Out:
# array([[34.777866]], dtype=float32)

# %%
plt.plot( ydata )
plt.plot( model.predict(xdata) ,'r--')
plt.show()
